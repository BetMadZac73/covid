# %%
# !pip install --upgrade plotly
import pandas as pd
import plotly.express as px

df_places = pd.read_excel('https://www.arcgis.com/sharing/rest/content/items/b5ed90611f3444c5bb95f83d03b9d805/data')
df_places = df_places[['LAD21CD', 'LAD21NM']].sort_values(by=['LAD21NM']).drop_duplicates('LAD21NM', keep='first').reset_index(drop=True)

# %%
def display_areas(df_places):
    i = 0
    for place in df_places.LAD21NM.tolist():
        print(f"{i:3d} - {place}")
        i+=1
        
#display_areas(df_places)
# Out:
#   0 - Adur
#   1 - Allerdale
#   2 - Amber Valley
#   3 - Arun
#   4 - Ashfield
#   5 - Ashford
#   6 - Babergh
#   7 - Barnsley
#   8 - Barrow-in-Furness
#   9 - Basildon
#  10 - Basingstoke and Deane
#  11 - Bassetlaw
#  12 - Bath and North East Somerset
#  13 - Bedford
#  14 - Birmingham
#  15 - Blaby
#  16 - Blackburn with Darwen
#  17 - Blaenau Gwent
#  18 - Bolsover
#  19 - Bolton
#  20 - Boston
#  21 - Bournemouth, Christchurch and Poole
#  22 - Bracknell Forest
#  23 - Bradford
#  24 - Braintree
#  25 - Breckland
#  26 - Brentwood
#  27 - Bridgend
#  28 - Brighton and Hove
#  29 - Broadland
#  30 - Bromsgrove
#  31 - Broxtowe
#  32 - Buckinghamshire
#  33 - Burnley
#  34 - Caerphilly
#  35 - Calderdale
#  36 - Cannock Chase
#  37 - Canterbury
#  38 - Cardiff
#  39 - Carlisle
#  40 - Carmarthenshire
#  41 - Castle Point
#  42 - Central Bedfordshire
#  43 - Ceredigion
#  44 - Charnwood
#  45 - Chelmsford
#  46 - Cheltenham
#  47 - Cherwell
#  48 - Cheshire East
#  49 - Cheshire West and Chester
#  50 - Chesterfield
#  51 - Chichester
#  52 - Chorley
#  53 - Colchester
#  54 - Conwy
#  55 - Copeland
#  56 - Cornwall
#  57 - Cotswold
#  58 - County Durham
#  59 - Coventry
#  60 - Craven
#  61 - Dacorum
#  62 - Darlington
#  63 - Dartford
#  64 - Denbighshire
#  65 - Derbyshire Dales
#  66 - Doncaster
#  67 - Dorset
#  68 - Dover
#  69 - East Cambridgeshire
#  70 - East Devon
#  71 - East Hampshire
#  72 - East Hertfordshire
#  73 - East Lindsey
#  74 - East Riding of Yorkshire
#  75 - East Staffordshire
#  76 - East Suffolk
#  77 - Eastleigh
#  78 - Eden
#  79 - Elmbridge
#  80 - Epping Forest
#  81 - Erewash
#  82 - Fenland
#  83 - Flintshire
#  84 - Forest of Dean
#  85 - Fylde
#  86 - Gateshead
#  87 - Gedling
#  88 - Gloucester
#  89 - Gravesham
#  90 - Great Yarmouth
#  91 - Guildford
#  92 - Gwynedd
#  93 - Halton
#  94 - Hambleton
#  95 - Harborough
#  96 - Harrogate
#  97 - Hart
#  98 - Hartlepool
#  99 - Herefordshire, County of
# 100 - Hertsmere
# 101 - High Peak
# 102 - Hinckley and Bosworth
# 103 - Horsham
# 104 - Huntingdonshire
# 105 - Hyndburn
# 106 - Isle of Anglesey
# 107 - Isle of Wight
# 108 - Isles of Scilly
# 109 - King's Lynn and West Norfolk
# 110 - Kirklees
# 111 - Knowsley
# 112 - Lancaster
# 113 - Leeds
# 114 - Lewes
# 115 - Lichfield
# 116 - Maidstone
# 117 - Maldon
# 118 - Malvern Hills
# 119 - Manchester
# 120 - Mansfield
# 121 - Medway
# 122 - Melton
# 123 - Mendip
# 124 - Merthyr Tydfil
# 125 - Mid Devon
# 126 - Mid Suffolk
# 127 - Mid Sussex
# 128 - Middlesbrough
# 129 - Milton Keynes
# 130 - Mole Valley
# 131 - Monmouthshire
# 132 - Neath Port Talbot
# 133 - New Forest
# 134 - Newark and Sherwood
# 135 - Newcastle upon Tyne
# 136 - Newcastle-under-Lyme
# 137 - Newport
# 138 - North Devon
# 139 - North East Derbyshire
# 140 - North East Lincolnshire
# 141 - North Hertfordshire
# 142 - North Kesteven
# 143 - North Lincolnshire
# 144 - North Norfolk
# 145 - North Northamptonshire
# 146 - North Somerset
# 147 - North Warwickshire
# 148 - North West Leicestershire
# 149 - Northumberland
# 150 - Oldham
# 151 - Oxford
# 152 - Pembrokeshire
# 153 - Pendle
# 154 - Peterborough
# 155 - Powys
# 156 - Preston
# 157 - Redcar and Cleveland
# 158 - Redditch
# 159 - Reigate and Banstead
# 160 - Rhondda Cynon Taf
# 161 - Ribble Valley
# 162 - Richmondshire
# 163 - Rochford
# 164 - Rossendale
# 165 - Rother
# 166 - Rotherham
# 167 - Rugby
# 168 - Rushcliffe
# 169 - Rutland
# 170 - Ryedale
# 171 - Scarborough
# 172 - Sedgemoor
# 173 - Sefton
# 174 - Selby
# 175 - Sevenoaks
# 176 - Sheffield
# 177 - Shepway
# 178 - Shropshire
# 179 - Slough
# 180 - Solihull
# 181 - Somerset West and Taunton
# 182 - South Cambridgeshire
# 183 - South Derbyshire
# 184 - South Gloucestershire
# 185 - South Hams
# 186 - South Holland
# 187 - South Kesteven
# 188 - South Lakeland
# 189 - South Norfolk
# 190 - South Oxfordshire
# 191 - South Ribble
# 192 - South Somerset
# 193 - South Staffordshire
# 194 - Southend-on-Sea
# 195 - St Albans
# 196 - St. Helens
# 197 - Stafford
# 198 - Staffordshire Moorlands
# 199 - Stockton-on-Tees
# 200 - Stratford-on-Avon
# 201 - Stroud
# 202 - Sunderland
# 203 - Surrey Heath
# 204 - Swale
# 205 - Swansea
# 206 - Swindon
# 207 - Tameside
# 208 - Tandridge
# 209 - Teignbridge
# 210 - Telford and Wrekin
# 211 - Tendring
# 212 - Test Valley
# 213 - Tewkesbury
# 214 - Thanet
# 215 - Three Rivers
# 216 - Tonbridge and Malling
# 217 - Torbay
# 218 - Torfaen
# 219 - Torridge
# 220 - Trafford
# 221 - Tunbridge Wells
# 222 - Uttlesford
# 223 - Vale of Glamorgan
# 224 - Vale of White Horse
# 225 - Wakefield
# 226 - Warrington
# 227 - Warwick
# 228 - Waverley
# 229 - Wealden
# 230 - Welwyn Hatfield
# 231 - West Berkshire
# 232 - West Devon
# 233 - West Lancashire
# 234 - West Lindsey
# 235 - West Northamptonshire
# 236 - West Oxfordshire
# 237 - West Suffolk
# 238 - Westminster
# 239 - Wigan
# 240 - Wiltshire
# 241 - Winchester
# 242 - Windsor and Maidenhead
# 243 - Wokingham
# 244 - Worcester
# 245 - Wrexham
# 246 - Wychavon
# 247 - Wyre
# 248 - Wyre Forest
# 249 - York

# %%
def pick_area(df_places):
    print('From the list above please choose the area by number')
    opt = int(input('input number => '))
    LAD21CD = df_places.loc[opt].LAD21CD
    LAD21NM = df_places.loc[opt].LAD21NM
    url = f'https://api.coronavirus.data.gov.uk/v2/data?areaType=ltla&areaCode={LAD21CD}&metric=newCasesBySpecimenDateAgeDemographics&format=csv'
    print(url)
    return url, LAD21NM, LAD21CD

#url, area, code = pick_area(df_places)

# %%
def draw_graph(url, area, code):
    
    ## first the permanent link for downloading, based on user choice
    df = pd.read_csv(url)
    ## the grouped counts we want to drop, they will cause double counting.
    df1 = df.query("age not in ['00_59', '60+', 'unassigned']")

    ## convert string date to a real date format
    df1['date'] = pd.to_datetime(df1['date'])

    ## calculate the most recent date 
    latest = df1.date.max().strftime("%Y-%m-%d")

    ## Create the first Bar Chart
    fig = px.bar(df1,
                x='date',
                y='cases',
                color='age',
                title=f'{area} - New Cases per day - by Age Group (UK Government Data)')

    ## Now we need to process the data to get x & y for total new cases per day
    dfx = df1.date.unique()[::-1]    # note we have to reverse the date list, otherwise graph is wrong direction. 
    dfy = df1.groupby('date').cases.sum()
    ## Create a second chart with scatter and then the trend line, we are going to use the trend line to add to the first graph
    fig2 = px.scatter(x=dfx, y=dfy, 
                          color_discrete_sequence=['#000000'],
                          trendline="rolling", trendline_options=dict(window=7))

    ## add the trend line -- data[1] -- to the first chart.
    fig.add_trace(fig2.data[1])

    # Add range slider and data selecter buttons as well. 
    fig.update_layout(
        xaxis=dict(
            rangeselector=dict(
            buttons=list([
                dict(count=14, label="fortnight", step="day", stepmode="backward"),
                dict(count=1, label="1m", step="month", stepmode="backward"),
                dict(count=6, label="6m", step="month", stepmode="backward"),
                dict(count=1, label="YTD", step="year", stepmode="todate"),
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(step="all")
                ])
            ),
        rangeslider=dict(visible=True), type="date"
        )
    )
 
    fig.show()
    
#draw_graph(url, area, code)
